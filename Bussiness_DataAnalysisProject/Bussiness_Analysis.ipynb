# %%
# import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# data load
df = pd.read_csv(r'/home/fatima/Desktop/SOFTGROWTECH_INTERNSHIP_FINAL_PROJECT/Bussiness_DataAnalysisProject/Super_.csv',encoding='latin1')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# over all profit and sales analysis
print(df['Sales'].sum())
print(df['Profit'].sum())
# Out:
# 2297200.8603
# 286397.0217

# %%
# check profit and sales by catagory data
df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
df.groupby('Category')[['Sales','Profit']].sum()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df.groupby('Category')[['Sales','Profit']].sum().plot(kind='bar')
plt.title('Sales and Profit by Category')
plt.xticks(rotation=0)
plt.xlabel('Product Category')
plt.ylabel('Sales and profit')
plt.show()

# %%
# check with sub category
df.groupby('Sub-Category')[['Sales','Profit']].sum()
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories   167380.3180  41936.6357
# Appliances    107532.1610  18138.0054
# Art            27118.7920   6527.7870
# Binders       203412.7330  30221.7633
# Bookcases     114879.9963  -3472.5560
# Chairs        328449.1030  26590.1663
# Copiers       149528.0300  55617.8249
# Envelopes      16476.4020   6964.1767
# Fasteners       3024.2800    949.5182
# Furnishings    91705.1640  13059.1436
# Labels         12486.3120   5546.2540
# Machines      189238.6310   3384.7569
# Paper          78479.2060  34053.5693
# Phones        330007.0540  44515.7306
# Storage       223843.6080  21278.8264
# Supplies       46673.5380  -1189.0995
# Tables        206965.5320 -17725.4811

# %%
# sub cat sale
colors = ['#FF5733', '#33FF57', '#3357FF', '#F1C40F', '#8E44AD', '#E74C3C', '#2ECC71', '#3498DB', '#F39C12', '#1ABC9C']
df.groupby('Sub-Category')['Sales'].sum().plot(kind='barh', color=colors)
plt.title('Sales by Sub-Category')
plt.xlabel('Sales')
plt.ylabel('Sub-Category Items')
plt.show()

# %%
# sub category by pro
df.groupby('Sub-Category')['Profit'].sum().plot(kind='barh',
                        color=colors                        )
plt.title('Profit by Sub Category')
plt.xlabel('profit')
plt.ylabel('Sub Category Items')
plt.show()

# %%
# Region wise sales
df.groupby('Region')[['Sales','Profit']].sum()
# Out:
#                Sales       Profit
# Region
# Central  501239.8908   39706.3625
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# West     725457.8245  108418.4489

# %%
# graph
df.groupby('Region')['Sales'].sum().plot(kind='pie',labels=['Central','East','South','West'],autopct='%1.1f%%')
plt.title('Regional Sales Percentage')
plt.show()

# %%
df.groupby('Region')['Profit'].sum().plot(kind='pie',labels=['Central','East','South','West'],autopct='%1.1f%%')
plt.title('Regional Profit Percentage')
plt.show()

# %%
# segmanet
df.groupby('Segment')['Sales'].sum()
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
df.groupby('Segment')['Sales'].sum().plot(kind='pie',labels=['Consumer','Corporate','Home Office'],autopct='%1.1f%%')
plt.title('Segmental percentage by Sales')
plt.show()

# %%
# yearly monthly sale trends
df['Order Date'] =pd.to_datetime(df['Order Date'])

# %%
import datetime as dt
df['Month'] = df['Order Date'].dt.month
df['Year']= df['Order Date'].dt.year

# %%
df.groupby('Month')['Sales'].sum().sort_values(ascending=False)
### conitnue ...
# Out:
# Month
# 11    352461.0710
# 12    325293.5035
# 9     307649.9457
# 3     205005.4888
# 10    200322.9847
# 8     159044.0630
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 4     137762.1286
# 1      94924.8356
# 2      59751.2514
# Name: Sales, dtype: float64

# %%
# graph
df.groupby('Month')['Sales'].sum().sort_values(ascending=False).plot(kind='bar',color=colors)
plt.title('Sales  Trend by Months')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# %%
# year
df.groupby('Year')['Sales'].sum()
# Out:
# Year
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %%
df.groupby('Year')['Sales'].sum().sort_values(ascending=False).plot(kind='bar',color=colors)
plt.title('Sales Trend by Year')
plt.xlabel('Years')
plt.ylabel('Sales')
plt.show()

# %%
# Date# df.groupby('Order ')['Sales'].sum().sort_index()
df= df.sort_values('Order Date')
daily_sales= df.groupby('Order Date')['Sales'].sum().reset_index()
plt.figure(figsize=(12,6))
plt.plot(daily_sales['Order Date'],daily_sales['Sales'],color='b',linewidth=2)

plt.grid(True,linestyle=
        '--',alpha=0.6)
plt.title('Trends Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# tp products
# df['Product Name'].unique()
data = df[['Product Name','Sales','Profit']]
data['Product Name'] = data['Product Name'].str.split(',')
data_exp = data.explode('Product Name')
data_exp['Product Name'] = data_exp['Product Name'].str.strip()
data_exp.groupby('Product Name')[['Sales','Profit']].sum().sort_values(by=['Sales','Profit'],ascending=False).head(10)
# Out:
#                                                          Sales        Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.8240  2.519993e+04
# Black                                               51529.3486  4.640893e+03
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.3840  7.753039e+03
# Cisco TelePresence System EX90 Videoconferencin...  22638.4800 -1.811078e+03
# HON 5400 Series Task Chairs for Big and Tall        21870.5760  1.136868e-13
# GBC DocuBind TL300 Electric Binding System          19823.4790  2.233505e+03
# GBC Ibimaster 500 Manual ProClick Binding System    19024.5000  7.609800e+02
# Hewlett Packard LaserJet 3310 Copier                18839.6860  6.983884e+03
# Custom Colors                                       18616.7050  5.556776e+02
# HP Designjet T520 Inkjet Large Format Printer -...  18374.8950  4.094977e+03

# %%
data_exp.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10).plot(kind='barh',color=colors)
plt.title('Top Sold Products')
plt.xlabel('Sales')
plt.ylabel('Products')
plt.show()

# %%
# proprofit
data_exp.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10).plot(kind='barh',color=colors)
plt.title('Top profitable Products')
plt.ylabel('products')
plt.ylabel("Profit")
plt.show()

# %%
# products and region
data_exp['city']=df['City']
data_exp.pivot_table(index='city',columns='Product Name',values=['Sales','Profit'],aggfunc='sum')
# Out:
#              Profit                                    \
# Product Name        "While you Were Out" Message Book
# city
# Aberdeen        NaN                               NaN
# Abilene         NaN                               NaN
# Akron           NaN                               NaN
# Albuquerque     NaN                               NaN
# Alexandria      NaN                               NaN
# ...             ...                               ...
# Woonsocket      NaN                               NaN
# Yonkers         NaN                               NaN
# York            NaN                               NaN
# Yucaipa         NaN                               NaN
# Yuma            NaN                               NaN
#
#                                                                             \
# Product Name #10 Gummed Flap White Envelopes #10 Self-Seal White Envelopes
# city
# Aberdeen                                 NaN                           NaN
# ...

# %%
df.pivot_table(index='City',values=['Sales','Profit'],aggfunc='sum').sort_values(by=['Sales','Profit'],ascending=False)
# Out:
#                    Profit       Sales
# City
# New York City  62036.9837  256368.161
# Los Angeles    30440.7579  175851.341
# Seattle        29156.0967  119540.742
# San Francisco  17507.3854  112669.092
# Philadelphia  -13837.7674  109077.013
# ...                   ...         ...
# Ormond Beach      -1.9656       2.808
# Pensacola         -1.4760       2.214
# Jupiter            0.1548       2.064
# Elyria            -1.3984       1.824
# Abilene           -3.7584       1.392
#
# [531 rows x 2 columns]

# %%
# top 10 citys by sales
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color=colors)
plt.title('Top 10 cities With high Sales')
plt.xlabel('Cities')
plt.ylabel('Sales')
plt.show()

# %%
# profit
df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color=colors)
plt.title('Top 10 cities With high Profit')
plt.xlabel('Cities')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## Business Data Analysis Summary
#
# This section covers the first ten analysis steps performed on the Superstore dataset. Each step looks at a different angle of the business performance.
#
# ## **1. Overall Sales and Profit**
# Total Sales came out to **2,297,200.86** and Total Profit came out to **286,397.02**. This gives a baseline of how the whole business is performing.
#
# ## **2. Category wise Performance**
# Technology had the highest sales at **836,154.03** and also the highest profit at **145,454.95**. Office Supplies had lower sales of **719,047.03** but still gave a healthy profit of **122,490.80**. Furniture had almost the same sales as Office Supplies at **741,999.80**, but the profit was very low at only **18,451.27**, showing this category is not very efficient.
#
# ## **3. Sub Category wise Performance**
# Chairs had the highest sales at **328,449.10**. Copiers gave the best profit at **55,617.82** even with moderate sales. Bookcases were a loss making sub category with profit of **negative 3,472.56**, which needs attention.
#
# ## **4. Region wise Performance**
# West region had the highest profit at **108,418.45** with sales of **725,457.82**. East region had the highest sales at **678,781.24** with profit of **91,522.78**. Central region was the weakest with sales of only **501,239.89** and the lowest profit of **39,706.36**.
#
#  ## **5. Segment wise Performance**
# Consumer segment dominates with **50.6 percent** of total sales. Corporate segment comes next with **30.7 percent**, and Home Office is the smallest at **18.7 percent** of sales.
#
# ## **6. Monthly Sales Trend**
# Sales peak in **November** at **352,461.07**, followed by **December** at **325,293.50**. The lowest sales month is **February** at only **59,751.25**, which shows a strong seasonal pattern around the year end holidays.
#
# ## **7. Top Products by Sales and Profit**
# The **Canon imageCLASS 2200 Advanced Copier** is the top performer, with sales of **61,599.82** and profit of **25,199.93**. Products like binding machines, copiers, and printers dominate the top profitable products list.
#
# ## **8. Yearly Sales Trend**
# Sales were highest in **2017** at close to **720,000**, followed by **2016** at around **590,000**. 2014 and 2015 were lower, close to **450,000** and **420,000**. This shows the business grew steadily over the years.
#
# ## **9. Daily Sales Trend**
# The daily sales trend line shows a lot of ups and downs across the years, with several sharp spikes reaching **25,000** to **28,000** on specific days. This is normal for order level data and shows sales are not steady day to day.
#
# ## **10. City wise Performance**
# **New York City** is the clear leader with sales of **256,368.16** and profit of **62,036.98**. **Los Angeles** follows with sales of **175,851.34** and profit of **30,440.76**. Interestingly, **Philadelphia** had good sales of **109,077.01** but a negative profit of **negative 13,837.77**, meaning heavy discounts or losses are happening there.
#
# ### Key Takeaways so far
# Technology is the strongest category, Furniture needs improvement, West region and Consumer segment drive the most business, November is the peak sales month, and some cities like Philadelphia show sales without profit, which is worth investigating further in the next set of tasks.

# %%
# discount vs profit
df[['Discount','Profit']].sort_values(by=['Discount','Profit'],ascending=False).head(10)
# Out:
#       Discount  Profit
# 9292       0.8 -0.9452
# 4101       0.8 -1.1100
# 8658       0.8 -1.3376
# 2106       0.8 -1.4016
# 8033       0.8 -1.4760
# 7548       0.8 -1.5715
# 1332       0.8 -1.7280
# 8024       0.8 -1.8270
# 987        0.8 -1.8904
# 8965       0.8 -1.9344

# %%
sb.set_theme(style='whitegrid')
plt.figure(figsize=(9,6))
sb.regplot(data =df,x='Discount',y='Profit',
           scatter_kws={
               'color':'#1f77b4',
               'alpha':0.6,
               's':50
           },line_kws={
               'color':'#e31a1c',
               'linewidth':2.5,
               
           }
           )
plt.title('Discount Impact on Profit')
plt.xlabel('Discount Applied (percentage/value)')
plt.ylabel('Net Profit',fontsize=11)
plt.axhline(0,color='black',linestyle='--',linewidth=1,alpha=0.5)
plt.tight_layout()
plt.show()
# df[['Discount','Profit']].sort_values(by=['Discount','Profit'],ascending=False).head(10).plot(kind='scatter',y='Profit',x='Discount')

# %%
df['Ship Mode'].value_counts().sort_values(ascending=False)
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df['Ship Mode'].value_counts(normalize=True)*100
# Out:
# Ship Mode
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: proportion, dtype: float64

# %%
df['Ship Mode'].value_counts().sort_values(ascending=False).plot(kind='bar',color=colors)
plt.title('Most Use Ship Mode')
plt.xticks(rotation=0)
plt.xlabel('Shipping Mode')
plt.ylabel('count')
plt.show()

# %%
# shipping mode with profit
df.groupby(['Ship Mode'])['Profit'].sum()
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %%
df.groupby(['Ship Mode'])['Sales'].sum()
# Out:
# Ship Mode
# First Class       3.514284e+05
# Same Day          1.283631e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %%
df.groupby(['Ship Mode'])['Sales'].sum().plot(kind='pie',autopct='%1.1f%%',labels=['First Class','Same Day','Second Class','Standard Class'],color=colors)
plt.title('Most Used Shipping Mode in Sales')
plt.show()

# %%
df.groupby(['Ship Mode'])[['Sales','Profit']].sum().plot(kind='bar',color=colors)
plt.title(' Profit and Sales With Mostly Used Shipping Mode')
plt.ylabel('Profit And Sales')
plt.xlabel('Shipping mode')
plt.xticks(rotation=0)
plt.show()

# %%
# difference between order date ship date
df[['Order Date','Ship Date']]
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df[['Order Date','Ship Date']]
# Out:
#      Order Date  Ship Date
# 7980 2014-01-03 2014-01-07
# 739  2014-01-04 2014-01-08
# 740  2014-01-04 2014-01-08
# 741  2014-01-04 2014-01-08
# 1759 2014-01-05 2014-01-12
# ...         ...        ...
# 5091 2017-12-30 2018-01-03
# 908  2017-12-30 2018-01-03
# 907  2017-12-30 2018-01-03
# 1296 2017-12-30 2018-01-03
# 906  2017-12-30 2018-01-03
#
# [9994 rows x 2 columns]

# %%
df['Delay_days'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Delay_days'].mean()
# Out:
# np.float64(3.958174904942966)

# %%
plt.figure(figsize=(8,5))
sb.histplot(data=df, x='Delay_days', bins=10)
plt.title('Order to  Ship Delay (Days)')
plt.xlabel('Delay Days')
plt.ylabel('Days Frequency')
plt.show()

# %%
# top 10 products with negative profit
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=True).head(15)
# Out:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                                      -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                                      -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                                      -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases                       -2876.1156
# Bush Advantage Collection Racetrack Conference Table                           -1934.3976
# GBC DocuBind P400 Electric Binding System                                      -1878.1662
# Cisco TelePresence System EX90 Videoconferencing Unit                          -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener                             -1299.1836
# Balt Solid Wood Round Tables                                                   -1201.0581
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables              -1148.4375
# ...

# %%
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=True).head(15).plot(kind='barh',color=colors)
plt.title('Top Products With less profit')
plt.ylabel('Products')
plt.xlabel('Profit')
plt.show()
# Out:
# /home/fatima/anaconda3/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 147 (\x93) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/fatima/anaconda3/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 148 (\x94) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer ID
# SM-20320    25043.050
# TC-20980    19052.218
# RB-19360    15117.339
# TA-21385    14595.620
# AB-10105    14473.571
# KL-16645    14175.229
# SC-20095    14142.334
# HL-15040    12873.298
# SE-20110    12209.438
# CC-12370    12129.072
# Name: Sales, dtype: float64

# %%
df.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head(15).plot(kind='barh',color=colors)
plt.title('Top Customers')
plt.ylabel('Sales')
plt.xlabel('Customers ID')
plt.show()

# %%
# check what most customer buys
df.groupby(['Customer ID','Product Name'])['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer ID  Product Name
# SJ-20125     Xerox 1964                                                              16
# RP-19270     Avery Durable Slant Ring Binders With Label Holder                      16
# SS-20515     GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb               15
# SE-20110     Wilson Jones Turn Tabs Binder Tool for Ring Binders                     14
# YS-21880     Letter Size Cart                                                        14
# SS-20515     Anker Ultra-Slim Mini Bluetooth 3.0 Wireless Keyboard                   14
# BP-11185     Logitech Wireless Headset h800                                          14
# GW-14605     PureGear Roll-On Screen Protector                                       14
# RC-19960     OIC Colored Binder Clips, Assorted Sizes                                14
# MP-18175     Wilson Jones Clip & Carry Folder Binder Tool for Ring Binders, Clear    14
# Name: Quantity, dtype: int64

# %%
# quantity vs sales
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7980    7981  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
# 739      740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 740      741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 741      742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 1759    1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 5091    5092  CA-2017-156720 2017-12-30 2018-01-03  Standard Class
# 908      909  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 907      908  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 1296    1297  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 906      907  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 7980    DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df.groupby('Quantity')[['Sales','Profit']].sum()
# Out:
#                 Sales      Profit
# Quantity
# 1          53251.9345   7440.4801
# 2         289091.4798  38448.4088
# 3         422060.6007  57015.5250
# 4         323670.9944  44223.3908
# 5         415661.6965  49516.5945
# 6         207122.3214  10325.4678
# 7         239908.3659  34286.9730
# 8         117760.1760  10856.7960
# 9         128505.5901  17687.8908
# 10         24056.6640   2044.1570
# 11         15772.4820   4293.3671
# 12         14868.4080   1185.0660
# 13         32338.1890   6348.9010
# 14         13131.9580   2724.0038

# %%
plt.figure(figsize=(9,6))
sb.scatterplot(data = df, x='Quantity', y='Sales',alpha=0.7)
plt.title('Relationship between Quantity and  Sales')
plt.ylabel('Sales')
plt.xlabel('Quantity Order')
plt.show()

# %%
plt.figure(figsize=(9,6))
sb.scatterplot(data = df, x='Quantity', y='Profit',alpha=1.0)
plt.title('Relationship between Quantity and profit')
plt.ylabel('Profit')
plt.xlabel('Quantity Order')
plt.show()

# %%
#segment and categor
df.groupby(['Segment','Category'])['Sales'].count()
# Out:
# Segment      Category
# Consumer     Furniture          1113
#              Office Supplies    3127
#              Technology          951
# Corporate    Furniture           646
#              Office Supplies    1820
#              Technology          554
# Home Office  Furniture           362
#              Office Supplies    1079
#              Technology          342
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(9,6))
df.groupby(['Segment','Category'])['Sales'].count().plot(kind='bar', color=colors)
plt.title('Transaction Frequency by Customer Segment and Product Category')
plt.ylabel('Prduct counts')
plt.xlabel('Category of Products')
# plt.xticks(rotation=25)
plt.show()

# %%
sub_cat_df = df.groupby('Sub-Category')[['Sales','Profit']].sum().reset_index()

sub_cat_df['Margin'] = (sub_cat_df['Profit'] / sub_cat_df['Sales'])*100
sub_cat_df=sub_cat_df.sort_values(by='Margin',ascending=False)

# %%
# profit margin calculation
plt.figure(figsize=(12,6))

sb.barplot(data = sub_cat_df,x='Sub-Category',y='Margin')
plt.xticks(rotation=90)
plt.title('Sub Category Profit Margin Percentage')
plt.xlabel('Sub Category Product')
plt.ylabel('Mergin Percentage')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['City'].unique()
# Out:
# <ArrowStringArray>
# [     'Houston',   'Naperville', 'Philadelphia',    'Henderson',
#        'Athens',  'Los Angeles',   'Huntsville',       'Laredo',
#   'Springfield',        'Dover',
#  ...
#       'Ontario',       'Renton',       'Canton',  'Summerville',
#     'Gladstone',     'Whittier',     'Palatine',      'Abilene',
#   'Port Orange',      'Danbury']
# Length: 531, dtype: str

# %%
df.groupby('City')['Profit'].sum().sort_values(ascending=True).head(12)
# Out:
# City
# Philadelphia   -13837.7674
# Houston        -10153.5485
# San Antonio     -7299.0502
# Lancaster       -7239.0684
# Chicago         -6654.5688
# Burlington      -3622.8772
# Dallas          -2846.5257
# Phoenix         -2790.8832
# Aurora          -2691.7386
# Jacksonville    -2323.8350
# Memphis         -1479.0400
# Louisville      -1430.3129
# Name: Profit, dtype: float64

# %%
# state wise profit high
df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(12).plot(kind='bar',color=colors)
plt.title('Most profitable cities')
plt.show()

# %%
df.groupby('City')['Profit'].sum().sort_values(ascending=True).head(12).plot(kind='bar',color=colors)
plt.title('Most NON profitable cities')
plt.show()

# %%
# correlation heat map

crr=df[['Profit','Sales','Discount','Quantity']].corr()

# %%
# plt.figure(figisze=(8,6))
sb.heatmap(data=crr, annot=True, cmap='Blues',linewidths=0.1)
plt.title('How Sales,Profit,Quantity and Discount Relates')
# plt.ylabel('Variables')

plt.show()
